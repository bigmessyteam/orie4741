# %%
import pandas as pd
import numpy as np

# %%
df_hotel=pd.read_csv("train.csv")

# %%
df_hotel.head(10)
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
# 5        1  2013-04-04 08:32:15       12                          187
# 6        1  2013-04-04 08:32:15       12                          187
# 7        1  2013-04-04 08:32:15       12                          187
# 8        1  2013-04-04 08:32:15       12                          187
# 9        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# ...

# %%
df_hotel_drop=df_hotel[df_hotel['visitor_hist_starrating'].notnull()]

# %%
df_new=df_hotel_drop.drop(['comp1_rate','comp1_inv','comp1_rate_percent_diff'],1)

# %%
df_new=df_new.drop(['comp2_rate','comp2_inv','comp2_rate_percent_diff'],1)

# %%
df_new=df_new.drop(['comp3_rate','comp3_inv','comp3_rate_percent_diff'],1)

# %%
df_new=df_new.drop(['comp4_rate','comp4_inv','comp4_rate_percent_diff'],1)

# %%
df_new=df_new.drop(['comp5_rate','comp5_inv','comp5_rate_percent_diff'],1)

# %%
df_new=df_new.drop(['comp6_rate','comp6_inv','comp6_rate_percent_diff'],1)

# %%
df_new=df_new.drop(['comp7_rate','comp7_inv','comp7_rate_percent_diff'],1)

# %%
df_new=df_new.drop(['comp8_rate','comp8_inv','comp8_rate_percent_diff'],1)

# %%
df_new.count()
# Out:
# srch_id                        505297
# date_time                      505297
# site_id                        505297
# visitor_location_country_id    505297
# visitor_hist_starrating        505297
# visitor_hist_adr_usd           505143
# prop_country_id                505297
# prop_id                        505297
# prop_starrating                505297
# prop_review_score              504546
# prop_brand_bool                505297
# prop_location_score1           505297
# prop_location_score2           387935
# prop_log_historical_price      505297
# position                       505297
# price_usd                      505297
# promotion_flag                 505297
# srch_destination_id            505297
# srch_length_of_stay            505297
# srch_booking_window            505297
# srch_adults_count              505297
# srch_children_count            505297
# srch_room_count                505297
# srch_saturday_night_bool       505297
# srch_query_affinity_score        5562
# ...

# %%
df_new=df_new.drop('srch_query_affinity_score',1)

# %%
df_new.head()
# Out:
#      srch_id            date_time  site_id  visitor_location_country_id  \
# 550       47  2013-01-14 22:28:43       14                          100
# 551       47  2013-01-14 22:28:43       14                          100
# 552       47  2013-01-14 22:28:43       14                          100
# 553       47  2013-01-14 22:28:43       14                          100
# 554       47  2013-01-14 22:28:43       14                          100
#
#      visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 550                     4.31                180.75              137     6618
# 551                     4.31                180.75              137    11747
# 552                     4.31                180.75              137    18311
# 553                     4.31                180.75              137    19599
# 554                     4.31                180.75              137    24002
#
# ...

# %%
df_new=df_new.drop('prop_location_score2',1)

# %%
df_new=df_new[df_new['orig_destination_distance'].notnull()]

# %%
df_new=df_new[df_new['prop_review_score'].notnull()]

# %%
df_new=df_new[df_new['visitor_hist_adr_usd'].notnull()]

# %%
df_new[df_new['booking_bool']==1].count()
# Out:
# srch_id                        10993
# date_time                      10993
# site_id                        10993
# visitor_location_country_id    10993
# visitor_hist_starrating        10993
# visitor_hist_adr_usd           10993
# prop_country_id                10993
# prop_id                        10993
# prop_starrating                10993
# prop_review_score              10993
# prop_brand_bool                10993
# prop_location_score1           10993
# prop_log_historical_price      10993
# position                       10993
# price_usd                      10993
# promotion_flag                 10993
# srch_destination_id            10993
# srch_length_of_stay            10993
# srch_booking_window            10993
# srch_adults_count              10993
# srch_children_count            10993
# srch_room_count                10993
# srch_saturday_night_bool       10993
# orig_destination_distance      10993
# random_bool                    10993
# ...

# %%
df_new.to_csv("train_clean.csv")
